# %% [markdown]
# <a href="https://colab.research.google.com/github/R0nMann/SD_Using_Python_Assignments/blob/main/Assignment_1/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Create a variable named carname and assign the value „Volvo‟ to it.
carname = "Volvo"
print(carname)
# Out:
# Volvo

# %%
#2. Create a variable named x and assign the value 50 to it.
x = 50
print(x)
# Out:
# 50

# %%
#3. Create a variable called z, assign x + y to it, and display the result.
x = 10
y = 20
z = x + y
print("z =",z)
# Out:
# z = 30

# %%
#4. Insert the correct syntax to assign values to multiple variables in one line:
#x __y___ z = "CSE", "IT", "ECE"
x,y,z = "CSE","IT","ECE"
print(x,y,z)
# Out:
# CSE IT ECE

# %%
#5. Insert the correct syntax to assign the same value to all three variables in one code line.
#X__Y__Z__ “RCC”
x=y=z="RCC"
print(x,y,z)
# Out:
# RCC RCC RCC

# %%
#6. Insert the correct keyword to make the variable x belong to the global scope.
#____________ x
global x

# %%
#7. Print different types of variable using “type” method (Solved example)
x = "Hello World"
print(x)
print(type(x))
x =50
print(x)
print(type(x))
x = 60.5
print(x)
print(type(x))
x = 3j
print(x)
print(type(x))
x = ["rcciit", "for", "rcciit"]
print(x)
print(type(x))
x = ("rcciit", "for", "rcciit")
print(x)
print(type(x))
x = range(10)
print(x)
print(type(x))
x = {"name": "Suraj", "age": 24}
print(x)
print(type(x))
x = {"rcciit", "for", "rcciit"}
print(x)
print(type(x))
x = frozenset({"rcciit", "for",
"rcciit","cse"})
print(x)
print(type(x))
x = True
print(x)
print(type(x))
x = b"Rcciit"
print(x)
print(type(x))
# Out:
# Hello World
# <class 'str'>
# 50
# <class 'int'>
# 60.5
# <class 'float'>
# 3j
# <class 'complex'>
# ['rcciit', 'for', 'rcciit']
# <class 'list'>
# ('rcciit', 'for', 'rcciit')
# <class 'tuple'>
# range(0, 10)
# <class 'range'>
# {'name': 'Suraj', 'age': 24}
# <class 'dict'>
# {'rcciit', 'for'}
# <class 'set'>
# frozenset({'cse', 'rcciit', 'for'})
# <class 'frozenset'>
# True
# <class 'bool'>
# b'Rcciit'
# <class 'bytes'>
